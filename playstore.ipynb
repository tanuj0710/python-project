# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('playstore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.columns #this will give you all columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.describe().columns #all numerical columns
# Out:
# Index(['Rating', 'Size'], dtype='object')

# %%
cat_cols=set(df.columns)-set(df.describe().columns) #to get categorical columns
cat_cols
# Out:
# {'Android Ver',
#  'App',
#  'Category',
#  'Content Rating',
#  'Current Ver',
#  'Genres',
#  'Installs',
#  'Last Updated',
#  'Price',
#  'Reviews',
#  'Type'}

# %%
df.isna().sum() #to get how many null values are present in each column
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
df.dropna(subset = ["Rating"], inplace=True) #to drop nan values from rating column

# %%
df.isna().sum() #the check weather nan values from rating are removed or not, yes they are removed
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
df[df['Android Ver'].isnull()] #checking the null values for Android Ver column. The record 10472 is different as its content rating is also unavalibale
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews          Size Installs  Type     Price Content Rating  \
# 4453      230  11000.000000   1,000+  Paid     $1.49       Everyone
# 4490      189   2100.000000  10,000+  Free         0       Everyone
# 10472    3.0M  21516.529524     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
df=df.drop(labels=10472,axis=0) #to drop the null value present in 10472th row in Android Ver
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df['Android Ver'].isnull()] #hence that row with index 10472 has been dropped
# Out:
#                          App         Category  Rating Reviews     Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230  11000.0
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189   2100.0
#
#      Installs  Type  Price Content Rating           Genres    Last Updated  \
# 4453   1,000+  Paid  $1.49       Everyone  Personalization   July 20, 2018
# 4490  10,000+  Free      0       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
df['Android Ver'].mode() #to calculate the mode for a given column i.e Android Ver
# Out:
# 0    4.1 and up
# dtype: object

# %%
df.fillna(df['Android Ver'].mode()[0], inplace = True) #to replace with mode the remaining null values

# %%
df[df['Android Ver'].isnull()] #hence null values are removed or replaced completely from Android ver column.
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df[df['Current Ver'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.isna().sum() #hence all null values have been removed
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df['Price']=df.Price.str.replace('$','') #by this method all the $sign will be removed

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Price'] = df['Price'].astype(float, errors = 'raise') #to convert Price object into Float

# %%
df.dtypes #now you can check Price has been converted into float
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Installs']=df.Installs.str.replace('+','') #to remove + sign from installs column

# %%
df['Installs']=df.Installs.str.replace(',','') #to remove , sign from installs column

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
# 2   87510   8700.0   5000000  Free    0.0       Everyone
# 3  215644  25000.0  50000000  Free    0.0           Teen
# 4     967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9366, dtype: float64

# %%
df.Installs.unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '100', '500', '10', '5', '50', '1'], dtype=object)

# %%
df.Rating.unique() #hence all the Ratings are between 1 and 5 only
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
df.Installs.value_counts()
# Out:
# 1000000       1577
# 10000000      1252
# 100000        1150
# 10000         1010
# 5000000        752
# 1000           713
# 500000         538
# 50000          467
# 5000           432
# 100000000      409
# 100            309
# 50000000       289
# 500            201
# 500000000       72
# 10              69
# 1000000000      58
# 50              56
# 5                9
# 1                3
# Name: Installs, dtype: int64

# %%
df['Installs'] = df['Installs'].astype(int, errors = 'raise') #converted to integers

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Reviews'] = df['Reviews'].astype(int, errors = 'raise')

# %%
df.dtypes #hence identified columns are converted to numeric
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size              float64
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df=df[df['Installs'] > df['Reviews']] #installs greater than reviews.
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df # now we have the final data with 9357 rows and 13 columns after data cleaning
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
plt.boxplot(df['Price']);

# %%
df.Price.unique() # hence there are outlines which are have value more than 50 and they are 6 values
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
#there are cases with price value reaching more than 50 which are outliners have to be removedas most of the prices are between 

df=df[df['Price'] <30]  
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.Price.unique() #hence all the values greater than 30 were removed
# Out:
# array([ 0.  ,  4.99,  3.99,  6.99,  7.99,  5.99,  2.99,  3.49,  1.99,
#         9.99,  7.49,  0.99,  9.  ,  5.49, 10.  , 24.99, 11.99, 16.99,
#        14.99, 29.99, 12.99,  2.49, 10.99,  1.5 , 19.99, 15.99,  3.95,
#         4.49,  1.7 ,  8.99,  1.49,  3.88, 17.99,  3.02,  1.76,  4.84,
#         4.77,  1.61,  2.5 ,  1.59,  6.49,  1.29, 18.99,  8.49,  1.75,
#        14.  ,  2.  ,  3.08,  2.59, 19.4 ,  3.9 ,  4.59, 15.46,  3.04,
#        13.99,  4.29,  3.28,  4.6 ,  1.  ,  2.95,  2.9 ,  1.97,  2.56,
#         1.2 ])

# %%
import seaborn as sns

# %%
plt.hist(df['Reviews']);

# %%
df.Reviews.value_counts()
# Out:
# 2           81
# 3           78
# 5           73
# 4           73
# 1           67
#             ..
# 137144       1
# 12215        1
# 17014705     1
# 10158        1
# 315390       1
# Name: Reviews, Length: 5988, dtype: int64

# %%
df=df[df['Reviews'] <1000000]  #hence we have limit our data with less than 1million reviews 
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.Installs.mean()
# Out:
# 4289530.085148285

# %%
df.Installs.median()
# Out:
# 100000.0

# %%
df.Installs.quantile(0.95) #95th percentile of installs
# Out:
# 10000000.0

# %%
df=df[df['Installs'] <df.Installs.quantile(0.95)]  #hence we have limit our data with less than 95th percentile of installs
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
import seaborn as sns

# %%
sns.distplot(df['Rating']);

# %% [raw]
# # this shows most of the ratings are between 4 and 5 as it is more skewed towrds left. This is basically showing that most of the
# # apps on playstore are good as most of them get the ratings between 4 and 5 out of 5

# %%
sns.jointplot(x='Size',y='Rating',data=df,kind='reg');

# %% [raw]
# we can see in this plot that as size is increasing ratings are also increasing which proves that the more the app size
# more the ratings as bigger apps have more features and they are more usefull. Also mostly apps have ratings between 4 and 5.

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size              float64
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
sns.pairplot(df,size=2,aspect=1.5);

# %% [raw]
# This shows that more the ratings more are the reviews, and reviews according to size are almost same, there is not much of a difference.

# %%
sns.barplot(x='Content Rating',y='Rating',data=df,estimator=np.median);

# %% [raw]
# estimator can be used as median or mean as it will plot graphs according to average values, we will get better result.

# %%
sns.jointplot(x='Price',y='Rating',data=df,kind='reg');

# %% [raw]
# hence no relation in this plot also, only lesser price apps were given more ratings.
